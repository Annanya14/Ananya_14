# %%
install.packages("caTools")
install.packages("class")
install.packages("ggplot2")


library(caTools)
library(class)
library(ggplot2)
# Out:
#   File "/tmp/ipython-input-728509426.py", line 7
#     library(class)
#             ^
# SyntaxError: invalid syntax

# %%
data(wine quality)
str(wine quality)
